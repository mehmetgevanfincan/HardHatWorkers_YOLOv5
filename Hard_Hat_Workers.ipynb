# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-165-ge382d4c Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
# !unzip -q /content/gdrive/MyDrive/safety_helmet.zip -d ../

# %%
# !pip install wandb -qU
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 898.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# Log in to your W&B account
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python train.py --img 640 --batch 16 --epochs 30 --data custom.yaml --weights yolov5x.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: mgevanfincan (mgevan). Use `wandb login --relogin` to force relogin
# train: weights=yolov5x.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/gdrive/MyDrive/testvideo/videoplayback.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/gdrive/MyDrive/testvideo/videoplayback.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-165-ge382d4c Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86186872 parameters, 0 gradients, 203.8 GFLOPs
# video 1/1 (1/985) /content/gdrive/MyDrive/testvideo/videoplayback.mp4: 640x640 3 helmets, 77.3ms
# video 1/1 (2/985) /content/gdrive/MyDrive/testvideo/videoplayback.mp4: 640x640 3 helmets, 75.8ms
# video 1/1 (3/985) /content/gdrive/MyDrive/testvideo/videoplayback.mp4: 640x640 3 helmets, 75.7ms
# ...
